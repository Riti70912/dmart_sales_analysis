# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
dmart = pd .read_csv('DMart.csv')

# %%
dmart.head()#here i have tried to show the names present in first of the dataset
# Out:
#                                 Name   Brand   Price  DiscountedPrice  \
# 0             Premia Badam (Almonds)  Premia   451.0            329.0
# 1             Premia Badam (Almonds)  Premia   109.0             85.0
# 2             Premia Badam (Almonds)  Premia   202.0            175.0
# 3  Nutraj California Almonds (Badam)  Nutraj   599.0            349.0
# 4  Nutraj California Almonds (Badam)  Nutraj  1549.0            659.0
#
#   Category         SubCategory Quantity Description  \
# 0  Grocery  Grocery/Dry Fruits   500 gm       India
# 1  Grocery  Grocery/Dry Fruits   100 gm       India
# 2  Grocery  Grocery/Dry Fruits   200 gm       India
# 3  Grocery          Dry Fruits   500 gm         USA
# 4  Grocery          Dry Fruits     1 kg         USA
#
#                     BreadCrumbs
# 0  Grocery > Grocery/Dry Fruits
# 1  Grocery > Grocery/Dry Fruits
# 2  Grocery > Grocery/Dry Fruits
# 3          Grocery > Dry Fruits
# 4          Grocery > Dry Fruits

# %%
dmart.tail() #here i have tried to show the names present in last of the dataset
# Out:
#                                            Name    Brand  Price  \
# 5184       Navneet Youva A4 Notebook - Assorted  Navneet   55.0
# 5185  Navneet Youva Longbook Journal - Assorted  Navneet   85.0
# 5186     Navneet Youva Long Notebook - Assorted  Navneet   55.0
# 5187      Navneet Youva Drawing Book - Assorted  Navneet  110.0
# 5188  Navneet Youva Canvas Board (10x12 Inches)  Navneet   90.0
#
#       DiscountedPrice         Category   SubCategory Quantity  \
# 5184             36.0  School Supplies  School Needs   1 Book
# 5185             69.0  School Supplies  School Needs   1 Book
# 5186             40.0  School Supplies  School Needs   1 Book
# 5187             72.0  School Supplies  School Needs   1 Book
# 5188             75.0  School Supplies  School Needs      1 U
#
#                                             Description  \
# 5184  OverviewEach book has an index page with label...
# 5185  OverviewStrong & sturdy case binding. Easy to ...
# ...

# %%
#Here correlation tells us about the relation we are having with the each numerical values and according to that only it plots the graph.
corr = dmart.corr() # Finding out the correlation between the features
sns.set(rc={'figure.figsize': (10,10)}) # Plotting the heatmap of correlation between features
sns.heatmap(corr, annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here i drop Description and Breadcrumbs column beacuse i am analysing the Price
# and discounted price so here we dont't need the description and Breadcrumbs.

# %%
dmart.drop("Description",axis=1,inplace=True)

# %%
dmart.head()
# Out:
#                                 Name   Brand   Price  DiscountedPrice  \
# 0             Premia Badam (Almonds)  Premia   451.0            329.0
# 1             Premia Badam (Almonds)  Premia   109.0             85.0
# 2             Premia Badam (Almonds)  Premia   202.0            175.0
# 3  Nutraj California Almonds (Badam)  Nutraj   599.0            349.0
# 4  Nutraj California Almonds (Badam)  Nutraj  1549.0            659.0
#
#   Category         SubCategory Quantity                   BreadCrumbs
# 0  Grocery  Grocery/Dry Fruits   500 gm  Grocery > Grocery/Dry Fruits
# 1  Grocery  Grocery/Dry Fruits   100 gm  Grocery > Grocery/Dry Fruits
# 2  Grocery  Grocery/Dry Fruits   200 gm  Grocery > Grocery/Dry Fruits
# 3  Grocery          Dry Fruits   500 gm          Grocery > Dry Fruits
# 4  Grocery          Dry Fruits     1 kg          Grocery > Dry Fruits

# %%
dmart.drop("BreadCrumbs",axis=1,inplace=True)
dmart.head()
# Out:
#                                 Name   Brand   Price  DiscountedPrice  \
# 0             Premia Badam (Almonds)  Premia   451.0            329.0
# 1             Premia Badam (Almonds)  Premia   109.0             85.0
# 2             Premia Badam (Almonds)  Premia   202.0            175.0
# 3  Nutraj California Almonds (Badam)  Nutraj   599.0            349.0
# 4  Nutraj California Almonds (Badam)  Nutraj  1549.0            659.0
#
#   Category         SubCategory Quantity
# 0  Grocery  Grocery/Dry Fruits   500 gm
# 1  Grocery  Grocery/Dry Fruits   100 gm
# 2  Grocery  Grocery/Dry Fruits   200 gm
# 3  Grocery          Dry Fruits   500 gm
# 4  Grocery          Dry Fruits     1 kg

# %%
dmart.shape #for finding the shape of the datasetA
# Out:
# (5189, 7)

# %%
# 2.DATATYPE OF EACH COLUMN

# %%
dmart.dtypes
# Out:
# Name                object
# Brand               object
# Price              float64
# DiscountedPrice    float64
# Category            object
# SubCategory         object
# Quantity            object
# dtype: object

# %% [markdown]
# # Statistical Analysis

# %%
dmart.describe() #description of the dataset
# Out:
#               Price  DiscountedPrice
# count   5188.000000      5188.000000
# mean     344.030360       236.669719
# std      601.034092       387.198716
# min        0.000000         0.000000
# 25%       85.000000        64.000000
# 50%      175.000000       125.000000
# 75%      345.000000       249.000000
# max    10990.000000      7999.000000

# %%
# to look upon the unique values which are present in Quantity Column

# %%
dmart['Brand'].unique()
# Out:
# array(['Premia', 'Nutraj', nan, 'Tata', 'Satyam', 'KMK',
#        'DMart Healthy Choice', 'Tata Sampann', 'Kanji Manji Kothari',
#        'ProV', 'Kalbavi', 'Kokan Gem', 'TATA', '24 Mantra Organic',
#        'Organic Tattva', 'Nutrela', '24 Mantra', 'Carnival', 'Saffola',
#        'Crown', 'Emperor', 'Falcon', 'Apis', 'King Solomon',
#        'Royal Delight', 'Shamim', 'Candor', 'Mahafruit', 'Morya',
#        'Keshar', 'Plain Jaggery', 'Laxmi', 'Miki', 'Fortune', 'Sunrich',
#        'Gemini', 'Sunday', 'Swaad', 'Dhara', 'Nature Fresh', 'Dalda',
#        'Sundrop', 'Sunny', 'Godrej', 'Aadhaar', 'Hudson', 'Svity Kolam',
#        'RiSO', 'Ricela', 'Gulab', 'Guinea', 'RRO', 'RRO Primio',
#        'Gramiyaa', 'Del Monte', 'Borges', 'Figaro', 'Leonardo',
#        'Bertolli', 'Patanjali', 'Tez', 'Idhayam', 'KLF', 'Tilsona',
#        'KPL Shudhi', 'Amul', 'Gowardhan', 'Aabad', 'Mother Dairy',
#        'Sagar', 'Prabhat', 'Chitale Dairy', 'Dynamix', 'Govind',
# ...

# %% [markdown]
# Looking at above values we can conclude that converting this column will become a hectinc task so we won't consider this column in our analysis

# %% [markdown]
# ## 1. Data cleaning

# %% [markdown]
# # Removing null values

# %%
# CHECKING DUPLICATES

# %%
dmart.duplicated().sum()
# Out:
# 5

# %% [markdown]
# Do we have null values

# %%
dmart.isnull()
# Out:
#        Name  Brand  Price  DiscountedPrice  Category  SubCategory  Quantity
# 0     False  False  False            False     False        False     False
# 1     False  False  False            False     False        False     False
# 2     False  False  False            False     False        False     False
# 3     False  False  False            False     False        False     False
# 4     False  False  False            False     False        False     False
# ...     ...    ...    ...              ...       ...          ...       ...
# 5184  False  False  False            False     False        False     False
# 5185  False  False  False            False     False        False     False
# 5186  False  False  False            False     False        False     False
# 5187  False  False  False            False     False        False     False
# 5188  False  False  False            False     False        False     False
#
# [5189 rows x 7 columns]

# %%
dmart.isnull().sum()
# Out:
# Name                 1
# Brand              400
# Price                1
# DiscountedPrice      1
# Category             3
# SubCategory          3
# Quantity             1
# dtype: int64

# %%
Priceofx_mean = dmart.Price.mean()

# %%
print(Priceofx_mean)
# Out:
# 344.03036044718584

# %%
dmart.Price.fillna(Priceofx_mean,inplace=True)

# %%
dmart.isnull().sum()
# Out:
# Name                 1
# Brand              400
# Price                0
# DiscountedPrice      1
# Category             3
# SubCategory          3
# Quantity             1
# dtype: int64

# %%
dmart[dmart['DiscountedPrice'].isnull()]
# Out:
#                                            Name    Brand      Price  \
# 4323  Elle 18 Nail Pops Nail Colour - Shade 125  Elle 18  344.03036
#
#       DiscountedPrice       Category              SubCategory Quantity
# 4323              NaN  Personal Care  Personal Care/Nail Care     5 ml

# %%
dmart['DiscountedPrice'].sort_values(ascending=False).head()
# Out:
# 2796    7999.0
# 3458    4999.0
# 3490    4699.0
# 3489    4149.0
# 4791    3999.0
# Name: DiscountedPrice, dtype: float64

# %%
DiscountedPricex= dmart.DiscountedPrice.median()

# %%
print(DiscountedPricex)
# Out:
# 125.0

# %%
dmart.DiscountedPrice.fillna(DiscountedPricex,inplace=True)

# %%
dmart.isnull().sum()
# Out:
# Name                 1
# Brand              400
# Price                0
# DiscountedPrice      0
# Category             3
# SubCategory          3
# Quantity             1
# dtype: int64

# %%
dmart.isnull().sum()
# Out:
# Name                 1
# Brand              400
# Price                0
# DiscountedPrice      0
# Category             3
# SubCategory          3
# Quantity             1
# dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
# 1. HISTOGRAM - sns.histplot()
sns.histplot(x='Price', data=dmart)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
# Enumerate function , with the help of this function we can plot as many numerical value graph present in the dataset excluding
#the object in our dataset.
`
cols = 3
rows = 3
num_cols = dmart.select_dtypes(exclude='object').columns
fig = plt.figure( figsize=(cols*5, rows*5))
for i, col in enumerate(num_cols):
#for i in num_cols:    
    ax=fig.add_subplot(rows,cols,i+1)
    
    sns.histplot(x = dmart[col], ax = ax)
    
fig.tight_layout()  
plt.show()
# Out:
#   Input In [82]
#     `
#     ^
# SyntaxError: invalid syntax

# %%
# 2. KDE PLOT - Kernal Density Plot - sns.kdeplot()
sns.kdeplot(x='Price', data=dmart, hue='Category')
# Out:
# C:\Users\UTTKARSH\AppData\Local\Temp\ipykernel_14800\3876909889.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x='Price', data=dmart, hue='Category')
# C:\Users\UTTKARSH\AppData\Local\Temp\ipykernel_14800\3876909889.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x='Price', data=dmart, hue='Category')
# C:\Users\UTTKARSH\AppData\Local\Temp\ipykernel_14800\3876909889.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x='Price', data=dmart, hue='Category')
# C:\Users\UTTKARSH\AppData\Local\Temp\ipykernel_14800\3876909889.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x='Price', data=dmart, hue='Category')
# ...

# %%
# with histogram - sns.histplot(kde=TRUE)
sns.histplot(x='Price', data=dmart, kde=True)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
# 3. RUG PLOT - sns.rugplot()
sns.rugplot(x='DiscountedPrice', data=dmart, height=.03, color='darkblue')
sns.histplot(x='DiscountedPrice', data=dmart, kde=True)
# Out:
# <AxesSubplot:xlabel='DiscountedPrice', ylabel='Count'>

# %%
# 4. BOX PLOTS - sns.boxplot()
sns.boxplot(x=dmart['DiscountedPrice'])
# Out:
# <AxesSubplot:xlabel='DiscountedPrice'>

# %% [markdown]
# # Bi-variate Analysis

# %%
sns.boxplot(data=dmart.loc[:, ['Price', 'DiscountedPrice']])
# Out:
# <AxesSubplot:>

# %%
cols = 3
rows = 3
num_cols = dmart.select_dtypes(exclude='object').columns
fig = plt.figure(figsize= (15,9))
for i, col in enumerate(num_cols):
    
    ax=fig.add_subplot( rows, cols, i+1)
    
    sns.boxplot(x=dmart[col], ax=ax)
    
fig.tight_layout()  
plt.show()

# %%
dmart.dtypes
# Out:
# Name                object
# Brand               object
# Price              float64
# DiscountedPrice    float64
# Category            object
# SubCategory         object
# Quantity            object
# dtype: object

# %%
dmart.Category.value_counts()
# Out:
# Personal Care                    1234
# Packaged Food                    1125
# Home & Kitchen                    880
# Grocery                           840
# Dairy & Beverages                 429
# Specials                          187
# Clothing & Accessories             97
# Fruits & Vegetables                78
# School Supplies                    69
# Appliances                         53
# Beauty & Cosmetics                 46
# Raincoat                           33
# DMart Grocery                      31
# Plant Container                    23
# Tableware                          18
# Backpacks                          13
# Zebronics                           5
# Motorbike Helmets                   4
# Baby & Kids                         4
# Geep                                3
# Kitchen Aprons                      3
# Butterfly                           2
# Computer Accessories                2
# Joyo Plastics                       2
# Pigeon                              1
# ...

# %%
dmart.Category.value_counts(normalize = True)
# Out:
# Personal Care                    0.237948
# Packaged Food                    0.216930
# Home & Kitchen                   0.169688
# Grocery                          0.161975
# Dairy & Beverages                0.082723
# Specials                         0.036059
# Clothing & Accessories           0.018704
# Fruits & Vegetables              0.015040
# School Supplies                  0.013305
# Appliances                       0.010220
# Beauty & Cosmetics               0.008870
# Raincoat                         0.006363
# DMart Grocery                    0.005978
# Plant Container                  0.004435
# Tableware                        0.003471
# Backpacks                        0.002507
# Zebronics                        0.000964
# Motorbike Helmets                0.000771
# Baby & Kids                      0.000771
# Geep                             0.000578
# Kitchen Aprons                   0.000578
# Butterfly                        0.000386
# ...

# %%
dmart.Category.value_counts(normalize = True).plot.bar()
plt.show()

# %%
dmart.Category.value_counts(normalize=True).plot.pie()
plt.show()

# %% [markdown]
# ## Correlation Test - Pearson and Spearman's Rank Relation

# %%
#person and spearman testing for correlation
import matplotlib
from matplotlib import pyplot
FirstSample = dmart[1:30]['Price']
SecondSample = dmart[1:30]['DiscountedPrice']

pyplot.plot(FirstSample,SecondSample)
pyplot.show()

# %%
#Spearman Rank Correlation
from scipy.stats import spearmanr
stat, p = spearmanr(FirstSample, SecondSample)

print('stat=%.3f, p=%5f' % (stat, p))
if p > 0.05:
    print('independent samples')
else:
    print('dependent samples')
# Out:
# stat=0.988, p=0.000000
# dependent samples

# %%
#pearson correlation
from scipy.stats import pearsonr
stat, p = pearsonr(FirstSample, SecondSample)

print('stat=%.3f, p=%5f' % (stat, p))
if p > 0.05:
    print('independent samples')
else:
    print('dependent samples')
# Out:
# stat=0.955, p=0.000000
# dependent samples

# %% [markdown]
# ### Multivariate analysis

# %%
dmart.groupby(by='Category').agg('mean')[['Price','DiscountedPrice']]
# Out:
#                                      Price  DiscountedPrice
# Category
# Appliances                     2469.207547      1689.113208
# Baby & Kids                     224.750000       223.750000
# Backpacks                      2188.384615      1002.076923
# Beauty & Cosmetics              399.739130       297.565217
# Butterfly                      4248.500000      1799.000000
# Clothing & Accessories          372.134021       239.463918
# Computer Accessories            349.000000       224.000000
# DMart Grocery                   343.612903       244.774194
# Dairy & Beverages               225.002657       177.706294
# Fruits & Vegetables              79.615385        60.730769
# Geep                            288.000000       109.000000
# Grocery                         311.383333       235.791667
# Home & Kitchen                  476.566330       311.638068
# Joyo Plastics                   907.500000       474.000000
# ...

# %%
sns.pairplot(dmart,hue='Category',height=5)

# %% [markdown]
# In the above graph we can see that i have perfromed multivariate analysis either we can tell it as also bivaraiate analysis in form of pairplot(this plot comprises with the mixture of many graphs in it) because my dataset consist of two numerical values and we know that it can be performed only on the numerical value.
